# %% [markdown]
# ## <center>Image Resizer Test<center>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('full-screen.png')

# %%
img
# Out:
# array([[[20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11],
#         ...,
#         [20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11]],
#
#        [[20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11],
#         ...,
#         [20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11]],
#
#        [[20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11],
#         ...,
#         [20, 14, 11],
#         [20, 14, 11],
#         [20, 14, 11]],
#
#        ...,
#
#        [[34, 34, 34],
#         [34, 34, 34],
#         [33, 33, 33],
#         ...,
#         [35, 35, 35],
#         [32, 32, 32],
#         [34, 34, 34]],
#
#        [[33, 33, 33],
#         [32, 32, 32],
#         [34, 34, 34],
#         ...,
#         [34, 34, 34],
#         [33, 33, 33],
#         [33, 33, 33]],
#
#        [[35, 35, 35],
#         [33, 33, 33],
#         [35, 35, 35],
#         ...,
#         [32, 32, 32],
#         [33, 33, 33],
#         [33, 33, 33]]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()

# %%
img = cv2.resize(img, (256, 256))
plt.imshow(img)
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
threshold_image = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)[1]
threshold_image = cv2.resize(threshold_image, (32, 32))
plt.imshow(threshold_image)
plt.show()
